# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoAzofeifa/AnalisisDatos/blob/main/LaboratorioMapas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Laboratorio Mapa con 5 Puntos de Localización de diferentes sedes de la Universidad Nacional de Costa Rica.
#Santiago Azofeifa Benavides.
#Jarren Chaves Vizcaino.
#Andrea Chacon Chacon.
import folium
from folium.plugins import MiniMap

# %%
CASA = folium.Map(location=(10.02074884419554, -84.1526482742486))

# %%
from folium.plugins import minimap
from branca.element import Figure

popuptext = '<b>CASA</b>'
my_map = folium.Map(location=[10.02074884419554, -84.1526482742486], zoom_start=16, titles='stamenterrain')

folium.Marker(location=[10.02074884419554, -84.1526482742486], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.02074884419554, -84.1526482742486], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltin="CASA").add_to(my_map)

minimap = MiniMap(title_layer='stamenterrain', position='bottomright')
my_map.add_child(minimap)

my_map.save('C:mapa.html')
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
#  Mapa con 5 Puntos de Localización de diferentes sedes de la Universidad Nacional de Costa Rica.

# %%
my_map = folium.Map(location=[9.412786495126474, -83.81533932588941], zoom_start=8, titles='stamenterrain')

#Punto 1
popuptext = '<b>Sede Brunca</b>'
folium.Marker(location=[9.412786495126474, -83.81533932588941], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.412786495126474, -83.81533932588941], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltin="Sede Brunca").add_to(my_map)

#Punto 2
popuptext = '<b>Sede Benjamín Nuñez</b>'
folium.Marker(location=[9.94877701408318, -84.13356531507556], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[9.94877701408318, -84.13356531507556], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltin="Sede Benjamín Nuñez").add_to(my_map)

#Punto 3
popuptext = '<b>Sede Interuniversitaria de Alajuela</b>'
folium.Marker(location=[10.019825839486208, -84.19683740909134], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.019825839486208, -84.19683740909134], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltin="Sede Interuniversitaria de Alajuela").add_to(my_map)

#Punto 4
popuptext = '<b>Sede Liberia</b>'
folium.Marker(location=[10.617675530016735, -85.45109616024415], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.617675530016735, -85.45109616024415], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltin="Sede Liberia").add_to(my_map)

#Punto 5
popuptext = '<b>Sede Sarapiquí</b>'
folium.Marker(location=[10.319244993005107, -83.92235012939821], popup=popuptext, icon=folium.Icon(color="orange", icon="ok-sign")).add_to(my_map)
folium.Circle(location=[10.319244993005107, -83.92235012939821], color="purple", weight=6, fill_color="red", fill_opacity=0.5, tooltin="Sede Sarapiquí").add_to(my_map)


minimap = MiniMap(title_layer='stamenterrain', position='bottomright')
my_map.add_child(minimap)

my_map.save('C:mapaUNA.html')
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
